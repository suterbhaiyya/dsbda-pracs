# %%
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset
#titanic dataset
data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/titanic_data.csv')
#tips dataset
tips = load_dataset("tips")

# %%
sns.countplot(data['Survived'])
plt.show()

# %%
data['Sex'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.hist(data['Age'], bins=5)
plt.show()

# %%
sns.distplot(data['Age'])
plt.show()
# Out:
# <ipython-input-21-6f6f368e55c5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips)
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips)
plt.show()

# %%
sns.barplot(x='Pclass', y='Age', data=data)
plt.show()

# %%
sns.barplot(x='Pclass', y='Fare', hue='Sex', data=data)
plt.show()

# %%
sns.boxplot(x='Sex', y='Age', hue='Survived', data=data)
plt.show()

# %%
sns.kdeplot(data[data['Survived'] == 0]['Age'], color="blue", label="Survived=0")
sns.kdeplot(data[data['Survived'] == 1]['Age'], color="orange", label="Survived=1")
plt.legend()  # Add a legend to distinguish the lines
plt.show()

# %%
display(pd.crosstab(data['Pclass'], data['Survived']))
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(data['Pclass'], data['Survived']), annot=True, fmt="d")
plt.show()

# %%
sns.clustermap(pd.crosstab(data['Parch'], data['Survived']), annot=True, fmt="d")
plt.show()
